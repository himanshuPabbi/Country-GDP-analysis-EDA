# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("countries.csv")

# %%
df
# Out:
#      Rank   ID                   Country      Continent  Population  \
# 0       1  840             United States  North America   339996.56
# 1       2  156                     China           Asia  1425671.35
# 2       3  392                     Japan           Asia   123294.51
# 3       4  276                   Germany         Europe    83294.63
# 4       5  356                     India           Asia  1428627.66
# ..    ...  ...                       ...            ...         ...
# 207   208  729                     Sudan         Africa    48109.01
# 208   209  760                     Syria           Asia    23227.01
# 209   210  788                   Tunisia         Africa    12458.22
# 210   211  796  Turks and Caicos Islands  North America       46.06
# 211   212  804                   Ukraine         Europe    36744.63
#
#           IMF_GDP        UN_GDP  GDP_per_capita
# 0    2.669515e+13  1.862448e+13        78515.94
# 1    2.186548e+13  1.121828e+13        15336.97
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212 entries, 0 to 211
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rank            212 non-null    int64
#  1   ID              212 non-null    int64
#  2   Country         212 non-null    object
#  3   Continent       212 non-null    object
#  4   Population      212 non-null    float64
#  5   IMF_GDP         212 non-null    float64
#  6   UN_GDP          212 non-null    float64
#  7   GDP_per_capita  212 non-null    float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 13.4+ KB

# %%
df.describe()
# Out:
#              Rank          ID    Population       IMF_GDP        UN_GDP  \
# count  212.000000  212.000000  2.120000e+02  2.120000e+02  2.120000e+02
# mean   106.500000  429.320755  3.793169e+04  5.213021e+11  3.541058e+11
# std     61.343296  250.649887  1.439021e+05  2.448664e+12  1.576706e+12
# min      1.000000    4.000000  4.390000e+00  0.000000e+00  0.000000e+00
# 25%     53.750000  211.000000  1.247810e+03  2.880000e+09  4.638538e+09
# 50%    106.500000  429.000000  6.967350e+03  2.951600e+10  2.128999e+10
# 75%    159.250000  642.250000  2.756395e+04  2.265350e+11  1.592921e+11
# max    212.000000  894.000000  1.428628e+06  2.669515e+13  1.862448e+13
#
#        GDP_per_capita
# count      212.000000
# mean     19669.115472
# std      28036.352685
# min        278.430000
# 25%       2484.200000
# 50%       7481.425000
# 75%      23997.432500
# max     178196.570000

# %%
df.shape
# Out:
# (212, 8)

# %%
df.columns
# Out:
# Index(['Rank', 'ID', 'Country', 'Continent', 'Population', 'IMF_GDP', 'UN_GDP',
#        'GDP_per_capita'],
#       dtype='object')

# %%
df=df.drop("ID",axis=1)

# %%
sns.boxplot(df['Rank'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rank'>

# %%
sns.boxplot(df['Population'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Population'>

# %%
q1=df['Population'].quantile(0.25)

# %%
q3=df['Population'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['Population']>lower) & (df['Population']<upper)]

# %%
df
# Out:
#      Rank                   Country      Continent  Population       IMF_GDP  \
# 6       7                    France         Europe    64756.58  3.086226e+12
# 7       8                    Canada  North America    38781.29  2.362318e+12
# 8       9                     Italy         Europe    58870.76  2.169384e+12
# 10     11               South Korea           Asia    51784.06  1.919562e+12
# 11     12                 Australia        Oceania    26439.11  1.828394e+12
# ..    ...                       ...            ...         ...           ...
# 207   208                     Sudan         Africa    48109.01  0.000000e+00
# 208   209                     Syria           Asia    23227.01  0.000000e+00
# 209   210                   Tunisia         Africa    12458.22  0.000000e+00
# 210   211  Turks and Caicos Islands  North America       46.06  0.000000e+00
# 211   212                   Ukraine         Europe    36744.63  0.000000e+00
#
#            UN_GDP  GDP_per_capita
# ...

# %%
sns.boxplot(df['IMF_GDP'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='IMF_GDP'>

# %%
q1=df['IMF_GDP'].quantile(0.25)

# %%
q3=df['IMF_GDP'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['IMF_GDP']>lower) & (df['IMF_GDP']<upper)]

# %%
df
# Out:
#      Rank                   Country      Continent  Population       IMF_GDP  \
# 51     52                    Greece         Europe    10341.28  2.348080e+11
# 52     53                     Qatar           Asia     2716.39  2.283560e+11
# 53     54                Kazakhstan         Europe    19606.63  2.259280e+11
# 54     55                   Hungary         Europe    10156.24  2.194630e+11
# 55     56                   Algeria         Africa    45606.48  1.993820e+11
# ..    ...                       ...            ...         ...           ...
# 207   208                     Sudan         Africa    48109.01  0.000000e+00
# 208   209                     Syria           Asia    23227.01  0.000000e+00
# 209   210                   Tunisia         Africa    12458.22  0.000000e+00
# 210   211  Turks and Caicos Islands  North America       46.06  0.000000e+00
# 211   212                   Ukraine         Europe    36744.63  0.000000e+00
#
#            UN_GDP  GDP_per_capita
# ...

# %%
sns.boxplot(df['UN_GDP'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='UN_GDP'>

# %%
q1=df['UN_GDP'].quantile(0.25)

# %%
q3=df['UN_GDP'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['UN_GDP']>lower) & (df['UN_GDP']<upper)]

# %%
df
# Out:
#      Rank                   Country      Continent  Population       IMF_GDP  \
# 62     63                     Kenya         Africa    55100.59  1.191270e+11
# 63     64        Dominican Republic  North America    11332.97  1.165440e+11
# 65     66                      Oman           Asia     4644.38  1.102500e+11
# 66     67                  Bulgaria         Europe     6687.72  9.779800e+10
# 67     68                 Guatemala  North America    18092.03  9.598800e+10
# ..    ...                       ...            ...         ...           ...
# 206   207                  Anguilla  North America       15.90  0.000000e+00
# 207   208                     Sudan         Africa    48109.01  0.000000e+00
# 208   209                     Syria           Asia    23227.01  0.000000e+00
# 209   210                   Tunisia         Africa    12458.22  0.000000e+00
# 210   211  Turks and Caicos Islands  North America       46.06  0.000000e+00
#
#            UN_GDP  GDP_per_capita
# ...

# %%
sns.boxplot(df['GDP_per_capita'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GDP_per_capita'>

# %%
q1=df['GDP_per_capita'].quantile(0.25)

# %%
q3=df['GDP_per_capita'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['GDP_per_capita']>lower) & (df['GDP_per_capita']<upper)]

# %%
df
# Out:
#      Rank                   Country      Continent  Population       IMF_GDP  \
# 62     63                     Kenya         Africa    55100.59  1.191270e+11
# 63     64        Dominican Republic  North America    11332.97  1.165440e+11
# 65     66                      Oman           Asia     4644.38  1.102500e+11
# 66     67                  Bulgaria         Europe     6687.72  9.779800e+10
# 67     68                 Guatemala  North America    18092.03  9.598800e+10
# ..    ...                       ...            ...         ...           ...
# 206   207                  Anguilla  North America       15.90  0.000000e+00
# 207   208                     Sudan         Africa    48109.01  0.000000e+00
# 208   209                     Syria           Asia    23227.01  0.000000e+00
# 209   210                   Tunisia         Africa    12458.22  0.000000e+00
# 210   211  Turks and Caicos Islands  North America       46.06  0.000000e+00
#
#            UN_GDP  GDP_per_capita
# ...

# %%
country_population_df=df[['Country','Population']]

# %%
country_population_df
# Out:
#                       Country  Population
# 62                      Kenya    55100.59
# 63         Dominican Republic    11332.97
# 65                       Oman     4644.38
# 66                   Bulgaria     6687.72
# 67                  Guatemala    18092.03
# ..                        ...         ...
# 206                  Anguilla       15.90
# 207                     Sudan    48109.01
# 208                     Syria    23227.01
# 209                   Tunisia    12458.22
# 210  Turks and Caicos Islands       46.06
#
# [132 rows x 2 columns]

# %%
country_population_df=country_population_df.sort_values(by="Population",ascending=False)

# %%
country_population_df
# Out:
#           Country  Population
# 62          Kenya    55100.59
# 78        Myanmar    54578.00
# 87         Uganda    48582.33
# 207         Sudan    48109.01
# 187   Afghanistan    42239.85
# ..            ...         ...
# 191  Cook Islands       17.04
# 206      Anguilla       15.90
# 185         Nauru       12.78
# 186        Tuvalu       11.40
# 201    Montserrat        4.39
#
# [132 rows x 2 columns]

# %%
country_population_df=country_population_df.reset_index(drop=True)

# %%
country_population_df
# Out:
#           Country  Population
# 0           Kenya    55100.59
# 1         Myanmar    54578.00
# 2          Uganda    48582.33
# 3           Sudan    48109.01
# 4     Afghanistan    42239.85
# ..            ...         ...
# 127  Cook Islands       17.04
# 128      Anguilla       15.90
# 129         Nauru       12.78
# 130        Tuvalu       11.40
# 131    Montserrat        4.39
#
# [132 rows x 2 columns]

# %% [markdown]
# # Top 10 Country with highest Population

# %%
top_10_country_population_df=country_population_df[:10]

# %%
top_10_country_population_df
# Out:
#        Country  Population
# 0        Kenya    55100.59
# 1      Myanmar    54578.00
# 2       Uganda    48582.33
# 3        Sudan    48109.01
# 4  Afghanistan    42239.85
# 5   Uzbekistan    35163.94
# 6        Yemen    34449.83
# 7        Ghana    34121.99
# 8   Mozambique    33897.35
# 9        Nepal    30896.59

# %%
sns.barplot(x=top_10_country_population_df['Country'],y=top_10_country_population_df['Population'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Top 10 Country with lowest Population

# %%
country_population_df=df[['Country','Population']]

# %%
country_population_df
# Out:
#                       Country  Population
# 62                      Kenya    55100.59
# 63         Dominican Republic    11332.97
# 65                       Oman     4644.38
# 66                   Bulgaria     6687.72
# 67                  Guatemala    18092.03
# ..                        ...         ...
# 206                  Anguilla       15.90
# 207                     Sudan    48109.01
# 208                     Syria    23227.01
# 209                   Tunisia    12458.22
# 210  Turks and Caicos Islands       46.06
#
# [132 rows x 2 columns]

# %%
country_population_df=country_population_df.sort_values(by="Population")

# %%
country_population_df=country_population_df.reset_index(drop=True)

# %%
bottom_10_country_population_df=country_population_df[:10]

# %%
sns.barplot(x=bottom_10_country_population_df['Country'],y=bottom_10_country_population_df['Population'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Top 10 Country with highest GDP per capita

# %%
df
# Out:
#      Rank                   Country      Continent  Population       IMF_GDP  \
# 62     63                     Kenya         Africa    55100.59  1.191270e+11
# 63     64        Dominican Republic  North America    11332.97  1.165440e+11
# 65     66                      Oman           Asia     4644.38  1.102500e+11
# 66     67                  Bulgaria         Europe     6687.72  9.779800e+10
# 67     68                 Guatemala  North America    18092.03  9.598800e+10
# ..    ...                       ...            ...         ...           ...
# 206   207                  Anguilla  North America       15.90  0.000000e+00
# 207   208                     Sudan         Africa    48109.01  0.000000e+00
# 208   209                     Syria           Asia    23227.01  0.000000e+00
# 209   210                   Tunisia         Africa    12458.22  0.000000e+00
# 210   211  Turks and Caicos Islands  North America       46.06  0.000000e+00
#
#            UN_GDP  GDP_per_capita
# ...

# %%
top_10_country_highest_GDP_df=df[['Country','GDP_per_capita']]

# %%
top_10_country_highest_GDP_df
# Out:
#                       Country  GDP_per_capita
# 62                      Kenya         2161.99
# 63         Dominican Republic        10283.62
# 65                       Oman        23738.35
# 66                   Bulgaria        14623.53
# 67                  Guatemala         5305.54
# ..                        ...             ...
# 206                  Anguilla        21229.04
# 207                     Sudan         1722.91
# 208                     Syria          954.19
# 209                   Tunisia         3347.47
# 210  Turks and Caicos Islands        19919.90
#
# [132 rows x 2 columns]

# %%
top_10_country_highest_GDP_df=top_10_country_highest_GDP_df.sort_values(by="GDP_per_capita",ascending=False)

# %%
top_10_country_highest_GDP_df=top_10_country_highest_GDP_df.reset_index(drop=True)

# %%
top_10_country_highest_GDP_df
# Out:
#                       Country  GDP_per_capita
# 0                       Malta        34812.66
# 1                     Bahamas        33032.57
# 2                    Slovenia        32971.09
# 3               New Caledonia        32238.92
# 4                       Aruba        31944.82
# ..                        ...             ...
# 127  Central African Republic          501.02
# 128                Madagascar          500.86
# 129              Sierra Leone          485.26
# 130               Afghanistan          479.05
# 131                   Burundi          278.43
#
# [132 rows x 2 columns]

# %%
sns.barplot(x=top_10_country_highest_GDP_df['Country'][:10],y=top_10_country_highest_GDP_df['GDP_per_capita'][:10])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Bottom 10 Country with Lowest GDP per capita

# %%
df
# Out:
#      Rank                   Country      Continent  Population       IMF_GDP  \
# 62     63                     Kenya         Africa    55100.59  1.191270e+11
# 63     64        Dominican Republic  North America    11332.97  1.165440e+11
# 65     66                      Oman           Asia     4644.38  1.102500e+11
# 66     67                  Bulgaria         Europe     6687.72  9.779800e+10
# 67     68                 Guatemala  North America    18092.03  9.598800e+10
# ..    ...                       ...            ...         ...           ...
# 206   207                  Anguilla  North America       15.90  0.000000e+00
# 207   208                     Sudan         Africa    48109.01  0.000000e+00
# 208   209                     Syria           Asia    23227.01  0.000000e+00
# 209   210                   Tunisia         Africa    12458.22  0.000000e+00
# 210   211  Turks and Caicos Islands  North America       46.06  0.000000e+00
#
#            UN_GDP  GDP_per_capita
# ...

# %%
bottom_10_country_lowest_GDP_df=df[['Country','GDP_per_capita']]

# %%
bottom_10_country_lowest_GDP_df
# Out:
#                       Country  GDP_per_capita
# 62                      Kenya         2161.99
# 63         Dominican Republic        10283.62
# 65                       Oman        23738.35
# 66                   Bulgaria        14623.53
# 67                  Guatemala         5305.54
# ..                        ...             ...
# 206                  Anguilla        21229.04
# 207                     Sudan         1722.91
# 208                     Syria          954.19
# 209                   Tunisia         3347.47
# 210  Turks and Caicos Islands        19919.90
#
# [132 rows x 2 columns]

# %%
bottom_10_country_lowest_GDP_df=bottom_10_country_lowest_GDP_df.sort_values(by="GDP_per_capita")

# %%
bottom_10_country_lowest_GDP_df=bottom_10_country_lowest_GDP_df.reset_index(drop=True)

# %%
bottom_10_country_lowest_GDP_df
# Out:
#                       Country  GDP_per_capita
# 0                     Burundi          278.43
# 1                 Afghanistan          479.05
# 2                Sierra Leone          485.26
# 3                  Madagascar          500.86
# 4    Central African Republic          501.02
# ..                        ...             ...
# 127                     Aruba        31944.82
# 128             New Caledonia        32238.92
# 129                  Slovenia        32971.09
# 130                   Bahamas        33032.57
# 131                     Malta        34812.66
#
# [132 rows x 2 columns]

# %%
sns.barplot(x=bottom_10_country_lowest_GDP_df['Country'][:10],y=bottom_10_country_lowest_GDP_df['GDP_per_capita'][:10])
plt.xticks(rotation=90)
plt.show()

# %%
df
# Out:
#      Rank                   Country      Continent  Population       IMF_GDP  \
# 62     63                     Kenya         Africa    55100.59  1.191270e+11
# 63     64        Dominican Republic  North America    11332.97  1.165440e+11
# 65     66                      Oman           Asia     4644.38  1.102500e+11
# 66     67                  Bulgaria         Europe     6687.72  9.779800e+10
# 67     68                 Guatemala  North America    18092.03  9.598800e+10
# ..    ...                       ...            ...         ...           ...
# 206   207                  Anguilla  North America       15.90  0.000000e+00
# 207   208                     Sudan         Africa    48109.01  0.000000e+00
# 208   209                     Syria           Asia    23227.01  0.000000e+00
# 209   210                   Tunisia         Africa    12458.22  0.000000e+00
# 210   211  Turks and Caicos Islands  North America       46.06  0.000000e+00
#
#            UN_GDP  GDP_per_capita
# ...

# %% [markdown]
# # Top 10 Country with highest IMF_GDP

# %%
Top_10_country_highest_IMF_GDP_df=df[['Country','IMF_GDP']]

# %%
Top_10_country_highest_IMF_GDP_df
# Out:
#                       Country       IMF_GDP
# 62                      Kenya  1.191270e+11
# 63         Dominican Republic  1.165440e+11
# 65                       Oman  1.102500e+11
# 66                   Bulgaria  9.779800e+10
# 67                  Guatemala  9.598800e+10
# ..                        ...           ...
# 206                  Anguilla  0.000000e+00
# 207                     Sudan  0.000000e+00
# 208                     Syria  0.000000e+00
# 209                   Tunisia  0.000000e+00
# 210  Turks and Caicos Islands  0.000000e+00
#
# [132 rows x 2 columns]

# %%
Top_10_country_highest_IMF_GDP_df=Top_10_country_highest_IMF_GDP_df.sort_values(by="IMF_GDP",ascending=False)

# %%
Top_10_country_highest_IMF_GDP_df
# Out:
#                       Country       IMF_GDP
# 62                      Kenya  1.191270e+11
# 63         Dominican Republic  1.165440e+11
# 65                       Oman  1.102500e+11
# 66                   Bulgaria  9.779800e+10
# 67                  Guatemala  9.598800e+10
# ..                        ...           ...
# 194                 Palestine  0.000000e+00
# 193          French Polynesia  0.000000e+00
# 191              Cook Islands  0.000000e+00
# 187               Afghanistan  0.000000e+00
# 210  Turks and Caicos Islands  0.000000e+00
#
# [132 rows x 2 columns]

# %%
Top_10_country_highest_IMF_GDP_df=Top_10_country_highest_IMF_GDP_df.reset_index(drop=True)

# %%
Top_10_country_highest_IMF_GDP_df
# Out:
#                       Country       IMF_GDP
# 0                       Kenya  1.191270e+11
# 1          Dominican Republic  1.165440e+11
# 2                        Oman  1.102500e+11
# 3                    Bulgaria  9.779800e+10
# 4                   Guatemala  9.598800e+10
# ..                        ...           ...
# 127                 Palestine  0.000000e+00
# 128          French Polynesia  0.000000e+00
# 129              Cook Islands  0.000000e+00
# 130               Afghanistan  0.000000e+00
# 131  Turks and Caicos Islands  0.000000e+00
#
# [132 rows x 2 columns]

# %%
sns.barplot(x=Top_10_country_highest_IMF_GDP_df['Country'][:10],y=Top_10_country_highest_IMF_GDP_df['IMF_GDP'][:10])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Bottom 20 Country with Lowest IMF_GDP

# %%
Bottom_10_IMF_GDP_df=df[['Country','IMF_GDP']]

# %%
Bottom_10_IMF_GDP_df
# Out:
#                       Country       IMF_GDP
# 62                      Kenya  1.191270e+11
# 63         Dominican Republic  1.165440e+11
# 65                       Oman  1.102500e+11
# 66                   Bulgaria  9.779800e+10
# 67                  Guatemala  9.598800e+10
# ..                        ...           ...
# 206                  Anguilla  0.000000e+00
# 207                     Sudan  0.000000e+00
# 208                     Syria  0.000000e+00
# 209                   Tunisia  0.000000e+00
# 210  Turks and Caicos Islands  0.000000e+00
#
# [132 rows x 2 columns]

# %%
Bottom_10_IMF_GDP_df=Bottom_10_IMF_GDP_df.sort_values(by="IMF_GDP",ascending=True)

# %%
Bottom_10_IMF_GDP_df
# Out:
#                       Country       IMF_GDP
# 210  Turks and Caicos Islands  0.000000e+00
# 187               Afghanistan  0.000000e+00
# 189    British Virgin Islands  0.000000e+00
# 191              Cook Islands  0.000000e+00
# 193          French Polynesia  0.000000e+00
# ..                        ...           ...
# 67                  Guatemala  9.598800e+10
# 66                   Bulgaria  9.779800e+10
# 65                       Oman  1.102500e+11
# 63         Dominican Republic  1.165440e+11
# 62                      Kenya  1.191270e+11
#
# [132 rows x 2 columns]

# %%
Bottom_10_IMF_GDP_df=Bottom_10_IMF_GDP_df.reset_index(drop=True)

# %%
Bottom_10_IMF_GDP_df
# Out:
#                       Country       IMF_GDP
# 0    Turks and Caicos Islands  0.000000e+00
# 1                 Afghanistan  0.000000e+00
# 2      British Virgin Islands  0.000000e+00
# 3                Cook Islands  0.000000e+00
# 4            French Polynesia  0.000000e+00
# ..                        ...           ...
# 127                 Guatemala  9.598800e+10
# 128                  Bulgaria  9.779800e+10
# 129                      Oman  1.102500e+11
# 130        Dominican Republic  1.165440e+11
# 131                     Kenya  1.191270e+11
#
# [132 rows x 2 columns]

# %%
sns.barplot(x=Bottom_10_IMF_GDP_df['Country'][:20],y=Bottom_10_IMF_GDP_df['IMF_GDP'][:20])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Top 10 Country with highest UN_GDP

# %%
df
# Out:
#      Rank                   Country      Continent  Population       IMF_GDP  \
# 62     63                     Kenya         Africa    55100.59  1.191270e+11
# 63     64        Dominican Republic  North America    11332.97  1.165440e+11
# 65     66                      Oman           Asia     4644.38  1.102500e+11
# 66     67                  Bulgaria         Europe     6687.72  9.779800e+10
# 67     68                 Guatemala  North America    18092.03  9.598800e+10
# ..    ...                       ...            ...         ...           ...
# 206   207                  Anguilla  North America       15.90  0.000000e+00
# 207   208                     Sudan         Africa    48109.01  0.000000e+00
# 208   209                     Syria           Asia    23227.01  0.000000e+00
# 209   210                   Tunisia         Africa    12458.22  0.000000e+00
# 210   211  Turks and Caicos Islands  North America       46.06  0.000000e+00
#
#            UN_GDP  GDP_per_capita
# ...

# %%
Top_10_country_highest_UN_GDP_df=df[['Country','UN_GDP']]

# %%
Top_10_country_highest_UN_GDP_df
# Out:
#                       Country        UN_GDP
# 62                      Kenya  7.052598e+10
# 63         Dominican Republic  7.158359e+10
# 65                       Oman  6.317096e+10
# 66                   Bulgaria  5.323964e+10
# 67                  Guatemala  6.876292e+10
# ..                        ...           ...
# 206                  Anguilla  3.375205e+08
# 207                     Sudan  8.288740e+10
# 208                     Syria  2.216308e+10
# 209                   Tunisia  4.170356e+10
# 210  Turks and Caicos Islands  9.175505e+08
#
# [132 rows x 2 columns]

# %%
Top_10_country_highest_UN_GDP_df=Top_10_country_highest_UN_GDP_df.sort_values(by="UN_GDP",ascending=False)

# %%
Top_10_country_highest_UN_GDP_df
# Out:
#                 Country        UN_GDP
# 207               Sudan  8.288740e+10
# 69            Sri Lanka  8.132197e+10
# 63   Dominican Republic  7.158359e+10
# 62                Kenya  7.052598e+10
# 67            Guatemala  6.876292e+10
# ..                  ...           ...
# 183    Marshall Islands  1.830000e+08
# 184            Kiribati  1.736551e+08
# 185               Nauru  1.034698e+08
# 201          Montserrat  6.205138e+07
# 186              Tuvalu  3.669718e+07
#
# [132 rows x 2 columns]

# %%
Top_10_country_highest_UN_GDP_df=Top_10_country_highest_UN_GDP_df.reset_index(drop=True)

# %%
Top_10_country_highest_UN_GDP_df
# Out:
#                 Country        UN_GDP
# 0                 Sudan  8.288740e+10
# 1             Sri Lanka  8.132197e+10
# 2    Dominican Republic  7.158359e+10
# 3                 Kenya  7.052598e+10
# 4             Guatemala  6.876292e+10
# ..                  ...           ...
# 127    Marshall Islands  1.830000e+08
# 128            Kiribati  1.736551e+08
# 129               Nauru  1.034698e+08
# 130          Montserrat  6.205138e+07
# 131              Tuvalu  3.669718e+07
#
# [132 rows x 2 columns]

# %%
sns.barplot(x=Top_10_country_highest_UN_GDP_df['Country'][:10],y=Top_10_country_highest_UN_GDP_df['UN_GDP'][:10])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Top 10 Country with lowest UN_GDP

# %%
df
# Out:
#      Rank                   Country      Continent  Population       IMF_GDP  \
# 62     63                     Kenya         Africa    55100.59  1.191270e+11
# 63     64        Dominican Republic  North America    11332.97  1.165440e+11
# 65     66                      Oman           Asia     4644.38  1.102500e+11
# 66     67                  Bulgaria         Europe     6687.72  9.779800e+10
# 67     68                 Guatemala  North America    18092.03  9.598800e+10
# ..    ...                       ...            ...         ...           ...
# 206   207                  Anguilla  North America       15.90  0.000000e+00
# 207   208                     Sudan         Africa    48109.01  0.000000e+00
# 208   209                     Syria           Asia    23227.01  0.000000e+00
# 209   210                   Tunisia         Africa    12458.22  0.000000e+00
# 210   211  Turks and Caicos Islands  North America       46.06  0.000000e+00
#
#            UN_GDP  GDP_per_capita
# ...

# %%
Bottom_10_country_lowest_UN_GDP_df=df[['Country','UN_GDP']]

# %%
Bottom_10_country_lowest_UN_GDP_df
# Out:
#                       Country        UN_GDP
# 62                      Kenya  7.052598e+10
# 63         Dominican Republic  7.158359e+10
# 65                       Oman  6.317096e+10
# 66                   Bulgaria  5.323964e+10
# 67                  Guatemala  6.876292e+10
# ..                        ...           ...
# 206                  Anguilla  3.375205e+08
# 207                     Sudan  8.288740e+10
# 208                     Syria  2.216308e+10
# 209                   Tunisia  4.170356e+10
# 210  Turks and Caicos Islands  9.175505e+08
#
# [132 rows x 2 columns]

# %%
Bottom_10_country_lowest_UN_GDP_df=Bottom_10_country_lowest_UN_GDP_df.sort_values(by="UN_GDP")

# %%
Bottom_10_country_lowest_UN_GDP_df
# Out:
#                 Country        UN_GDP
# 186              Tuvalu  3.669718e+07
# 201          Montserrat  6.205138e+07
# 185               Nauru  1.034698e+08
# 184            Kiribati  1.736551e+08
# 183    Marshall Islands  1.830000e+08
# ..                  ...           ...
# 67            Guatemala  6.876292e+10
# 62                Kenya  7.052598e+10
# 63   Dominican Republic  7.158359e+10
# 69            Sri Lanka  8.132197e+10
# 207               Sudan  8.288740e+10
#
# [132 rows x 2 columns]

# %%
Bottom_10_country_lowest_UN_GDP_df=Bottom_10_country_lowest_UN_GDP_df.reset_index(drop=True)

# %%
Bottom_10_country_lowest_UN_GDP_df[:10]
# Out:
#                  Country       UN_GDP
# 0                 Tuvalu   36697185.0
# 1             Montserrat   62051375.0
# 2                  Nauru  103469824.0
# 3               Kiribati  173655146.0
# 4       Marshall Islands  183000000.0
# 5           Cook Islands  290194195.0
# 6                  Palau  310248000.0
# 7             Micronesia  329895643.0
# 8               Anguilla  337520470.0
# 9  Sao Tome and Principe  342781695.0

# %%
sns.barplot(x=Bottom_10_country_lowest_UN_GDP_df['Country'][:10],y=Bottom_10_country_lowest_UN_GDP_df['UN_GDP'][:10])
plt.xticks(rotation=90)
plt.show()

# %%
sns.pairplot(data=df)
